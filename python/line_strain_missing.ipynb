# %%
import pandas as pd
import numpy as np
import datajoint as dj
from ibl_pipeline import subject, acquisition, behavior
from ibl_pipeline.analyses import behavior as behavior_analysis

# %%
sjs = subject.SubjectLab() * subject.Subject & 'subject_line is NULL or subject_strain is NULL' & 'subject_nickname not LIKE "human%"'
sjs = sjs.proj('lab_name','subject_nickname', 'subject_line', 'subject_strain', 'subject_source')

sjs = sjs.fetch(format='frame').reset_index()
sjs = sjs.sort_values(by=['lab_name', 'subject_nickname'])

# %%
pd.set_option('display.max_rows', 1000)
sjs
# Out:
#                              subject_uuid        lab_name    subject_nickname  \
# 145  a5b9ace4-b6cc-4b39-bf9b-c7c0e5d75560     angelakilab              CSP001
# 38   2d4291f4-a426-4fc4-9ef1-8d13bfd450f4     angelakilab              CSP003
# 64   4e4b8689-cfc7-40b1-986a-b8d642920c98     angelakilab              CSP004
# 91   64429801-3be6-40cf-ae95-1b74e4fa189e     angelakilab              CSP005
# 193  e68f8f75-0bb6-41e2-834c-5ddea4530382     angelakilab              CSP006
# 211  ffc2c8e8-7e92-459c-8d76-49723d5da0b2     angelakilab              CSP008
# 125  8e7516ef-bb4c-4289-98ec-f0980e56f667     angelakilab              CSP009
# 208  fd68d43c-7beb-4cd4-b6df-1a41f9689afc     angelakilab              CSP010
# 97   6b3b7541-e578-465a-a1d2-913a638f9b1f     angelakilab              CSP011
# 151  aafbcb4d-6d6f-4de5-8e3f-c4f4ddf6928b     angelakilab              CSP012
# 113  83f5fa81-021b-4134-8c78-0a67ed306a47     angelakilab              CSP013
# ...

# %%
print('# of animals without listed line or strain')
sjs.groupby(['lab_name'])['subject_nickname'].nunique().reset_index()
# Out:
# # of animals without listed line or strain
#          lab_name  subject_nickname
# 0     angelakilab                60
# 1   churchlandlab                26
# 2       cortexlab                 4
# 3        hoferlab                 8
# 4       mainenlab                45
# 5  mrsicflogellab                17
# 6    steinmetzlab                 3
# 7       wittenlab                12
# 8        zadorlab                37
