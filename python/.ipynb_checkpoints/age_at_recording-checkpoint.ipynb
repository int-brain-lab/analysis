# %%
# GENERAL THINGS FOR COMPUTING AND PLOTTING
import pandas as pd
import numpy as np
import os, sys, time
from datetime import datetime
from datetime import timedelta
import scipy as sp

# visualisation
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks", context="talk")

# ibl specific things
import datajoint as dj
from ibl_pipeline import subject, acquisition
ephys = dj.create_virtual_module('ephys', 'ibl_ephys')

pd.set_option('display.max_rows', 1000)

# %%
# all mice that made it to ready4ephys
all_ephys_sess = (subject.Subject * subject.SubjectLab * \
                  (acquisition.SessionProject & 'session_project = "ibl_neuropixel_brainwide_01"') * \
                                  (acquisition.Session & 'task_protocol LIKE "%ephysChoiceWorld%"') \
                 & ephys.DefaultCluster)
all_ephys_sess = all_ephys_sess.proj('subject_nickname', 'subject_birth_date', 'lab_name',
                    age_at_rec='DATEDIFF(session_start_time, subject_birth_date) / 30')

all_ephys_sess = all_ephys_sess.fetch(format='frame').reset_index()
all_ephys_sess = all_ephys_sess[~all_ephys_sess['age_at_rec'].isnull()]
all_ephys_sess['too_old'] = all_ephys_sess['age_at_rec'] > 7
all_ephys_sess['age_at_rec'] = all_ephys_sess['age_at_rec'].astype(float)

# %%
all_ephys_sess.groupby(['lab_name'])['age_at_rec'].describe()
#all_ephys_sess.groupby(['age_at_rec'])['subject_nickname'].unique()
# Out:
#                 count      mean       std     min       25%      50%  \
# lab_name
# angelakilab      10.0  5.983340  1.107912  4.8667  4.941650  5.98335
# churchlandlab    46.0  5.602898  0.657299  4.6333  5.008325  5.63330
# cortexlab        21.0  6.834919  0.982711  5.4667  5.600000  7.30000
# danlab           36.0  6.136114  1.297653  4.5000  5.424975  5.65000
# hoferlab         12.0  7.250000  0.814196  6.3000  6.391675  7.68335
# mrsicflogellab    8.0  9.033325  1.123204  7.9333  7.991675  9.03330
# wittenlab         6.0  7.416667  0.215763  7.2000  7.241650  7.38335
# zadorlab          7.0  7.880957  1.541631  6.2000  6.250000  9.06670
#
#                       75%      max
# lab_name
# angelakilab      7.024975   7.1000
# churchlandlab    6.091675   6.8333
# cortexlab        7.400000   8.7333
# danlab           6.608325  10.8000
# hoferlab         7.775025   8.6333
# mrsicflogellab  10.075025  10.1333
# wittenlab        7.550025   7.7333
# zadorlab         9.116650   9.1667

# %%
g = sns.FacetGrid(all_ephys_sess, col="lab_name", hue='too_old', col_wrap=4)
g = g.map(sns.distplot, "age_at_rec", rug=True, kde=False, bins=np.linspace(3, 12, 30))

# %%
g = sns.FacetGrid(all_ephys_sess, hue='too_old')
g = g.map(sns.distplot, "age_at_rec", rug=True, kde=False, bins=np.linspace(3, 12, 30))

# %%
all_ephys_sess.groupby(['lab_name', 'subject_nickname', 'too_old'])['age_at_rec'].describe()
# Out:
#                                          count       mean       std      min  \
# lab_name       subject_nickname too_old
# angelakilab    NYU-11           False      2.0   6.983350  0.023547   6.9667
#                                 True       3.0   7.066667  0.033350   7.0333
#                NYU-12           False      5.0   4.933340  0.052699   4.8667
# churchlandlab  CSHL045          False      4.0   6.783325  0.043029   6.7333
#                CSHL047          False      5.0   5.686660  0.121549   5.5667
#                CSHL049          False      6.0   5.250000  0.062347   5.1667
#                CSHL051          False      4.0   5.933325  0.071983   5.8667
#                CSHL052          False      5.0   6.333340  0.052699   6.2667
#                CSHL053          False      4.0   5.700000  0.072013   5.6333
#                CSHL054          False      2.0   6.083350  0.023547   6.0667
#                CSHL055          False      2.0   6.283350  0.023547   6.2667
#                CSHL059          False      8.0   4.741663  0.070709   4.6333
#                CSHL060          False      6.0   4.966667  0.078878   4.8667
# cortexlab      KS014            True       5.0   7.300000  0.052715   7.2333
#                KS016            True       5.0   7.346660  0.069103   7.2667
#                KS018            True       1.0   8.733300       NaN   8.7333
#                KS020            True       3.0   7.577800  0.083903   7.5000
#                KS022            False      2.0   5.550000  0.023617   5.5333
#                KS023            False      5.0   5.546660  0.069103   5.4667
# danlab         DY_006           True       2.0  10.733350  0.094257  10.6667
#                DY_008           False      3.0   6.633333  0.033350   6.6000
#                DY_009           False     10.0   6.620000  0.134434   6.4333
#                DY_010           False     12.0   5.411117  0.143789   5.2000
#                DY_011           False      7.0   5.600000  0.144023   5.4000
#                DY_013           False      2.0   4.600000  0.141421   4.5000
# hoferlab       SWC_014          False      5.0   6.373340  0.064134   6.3000
#                SWC_015          True       6.0   7.750000  0.062347   7.6667
#                SWC_021          True       1.0   8.633300       NaN   8.6333
# mrsicflogellab SWC_018          True       4.0  10.083325  0.043029  10.0333
#                SWC_023          True       4.0   7.983325  0.043029   7.9333
# wittenlab      ibl_witten_13    True       3.0   7.233333  0.033350   7.2000
#                ibl_witten_14    True       3.0   7.600000  0.120162   7.5000
# zadorlab       CSH_ZAD_001      True       4.0   9.116675  0.043029   9.0667
#                CSH_ZAD_011      False      3.0   6.233333  0.033350   6.2000
#
#                                                25%       50%        75%  \
# lab_name       subject_nickname too_old
# angelakilab    NYU-11           False     6.975025   6.98335   6.991675
#                                 True      7.050000   7.06670   7.083350
#                NYU-12           False     4.900000   4.93330   4.966700
# churchlandlab  CSHL045          False     6.758350   6.78335   6.808325
#                CSHL047          False     5.600000   5.63330   5.800000
#                CSHL049          False     5.208325   5.25000   5.291675
#                CSHL051          False     5.891675   5.91665   5.958300
#                CSHL052          False     6.300000   6.33330   6.366700
#                CSHL053          False     5.658350   5.68335   5.725000
#                CSHL054          False     6.075025   6.08335   6.091675
#                CSHL055          False     6.275025   6.28335   6.291675
#                CSHL059          False     4.691675   4.75000   4.800000
#                CSHL060          False     4.908325   4.96665   5.024975
# cortexlab      KS014            True      7.266700   7.30000   7.333300
#                KS016            True      7.300000   7.33330   7.400000
#                KS018            True      8.733300   8.73330   8.733300
#                KS020            True      7.533350   7.56670   7.616700
#                KS022            False     5.541650   5.55000   5.558350
#                KS023            False     5.500000   5.53330   5.600000
# danlab         DY_006           True     10.700025  10.73335  10.766675
#                DY_008           False     6.616650   6.63330   6.650000
#                DY_009           False     6.516675   6.61665   6.691675
#                DY_010           False     5.291675   5.41665   5.508325
#                DY_011           False     5.516650   5.56670   5.700000
#                DY_013           False     4.550000   4.60000   4.650000
# hoferlab       SWC_014          False     6.333300   6.36670   6.400000
#                SWC_015          True      7.708325   7.75000   7.791675
#                SWC_021          True      8.633300   8.63330   8.633300
# mrsicflogellab SWC_018          True     10.058350  10.08335  10.108325
#                SWC_023          True      7.958350   7.98335   8.008325
# wittenlab      ibl_witten_13    True      7.216650   7.23330   7.250000
#                ibl_witten_14    True      7.533350   7.56670   7.650000
# zadorlab       CSH_ZAD_001      True      9.091675   9.11665   9.141650
#                CSH_ZAD_011      False     6.216650   6.23330   6.250000
#
#                                              max
# lab_name       subject_nickname too_old
# angelakilab    NYU-11           False     7.0000
#                                 True      7.1000
#                NYU-12           False     5.0000
# churchlandlab  CSHL045          False     6.8333
#                CSHL047          False     5.8333
#                CSHL049          False     5.3333
#                CSHL051          False     6.0333
#                CSHL052          False     6.4000
#                CSHL053          False     5.8000
#                CSHL054          False     6.1000
#                CSHL055          False     6.3000
#                CSHL059          False     4.8333
#                CSHL060          False     5.0667
# cortexlab      KS014            True      7.3667
#                KS016            True      7.4333
#                KS018            True      8.7333
#                KS020            True      7.6667
#                KS022            False     5.5667
#                KS023            False     5.6333
# danlab         DY_006           True     10.8000
#                DY_008           False     6.6667
#                DY_009           False     6.8333
#                DY_010           False     5.6667
#                DY_011           False     5.8000
#                DY_013           False     4.7000
# hoferlab       SWC_014          False     6.4667
#                SWC_015          True      7.8333
#                SWC_021          True      8.6333
# mrsicflogellab SWC_018          True     10.1333
#                SWC_023          True      8.0333
# wittenlab      ibl_witten_13    True      7.2667
#                ibl_witten_14    True      7.7333
# zadorlab       CSH_ZAD_001      True      9.1667
#                CSH_ZAD_011      False     6.2667
