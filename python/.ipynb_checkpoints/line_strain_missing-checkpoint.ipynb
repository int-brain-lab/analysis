# %%
import pandas as pd
import numpy as np
import datajoint as dj
from ibl_pipeline import subject, acquisition, behavior
from ibl_pipeline.analyses import behavior as behavior_analysis
# Out:
# Connecting anneurai@datajoint.internationalbrainlab.org:3306
# Connected to https://alyx.internationalbrainlab.org as anneu

# %%
sjs = subject.SubjectUser * subject.SubjectLab() * subject.Subject & 'subject_line is NULL or subject_strain is NULL' & 'subject_nickname not LIKE "human%"'

# %%
sjs = sjs.proj('lab_name', 'responsible_user', 'subject_nickname', 'subject_line', 'subject_strain', 'subject_source')
sjs = sjs.fetch(format='frame').reset_index()
sjs = sjs.sort_values(by=['lab_name', 'responsible_user', 'subject_nickname'])

# %%
pd.set_option('display.max_rows', 1000)
sjs
# Out:
#                             subject_uuid responsible_user        lab_name  \
# 21  4372e7ab-0978-4aff-81eb-e922e8b69920   sfn_booth_user   churchlandlab
# 23  52a800fc-cbbc-45e9-97b1-ad6f6166e9af          valeria   churchlandlab
# 34  7c751b49-55a6-4eac-9bdb-367faf2a18ee          valeria   churchlandlab
# 20  3f854f88-7879-4368-9e0d-41edea3bfab9          valeria   churchlandlab
# 28  6318a191-5ee9-4c81-87d4-e2078572c525          valeria   churchlandlab
# 4   1208c089-8b8e-4a87-98f0-05a68fb18370          valeria   churchlandlab
# 57  f953fa3b-d24f-4c47-9550-b11c2b9f96f2          valeria   churchlandlab
# 2   063bc242-80a7-4356-abfe-bc9d475fa8e1          valeria   churchlandlab
# 11  24ccb0ca-c7cb-4cf0-844c-bd426af9bc56          valeria   churchlandlab
# 56  f3821028-b230-452d-886c-84aab766ca1e          valeria   churchlandlab
# 55  eee73e7a-a2eb-4949-91ae-a3d5a0375bd5          valeria   churchlandlab
# 29  64ff6fea-89a5-449d-a9f4-53f4b200e7db          valeria   churchlandlab
# 43  a7ccdd67-8443-458a-a0ba-2f76a826a7a7          valeria   churchlandlab
# 54  dcf2d0f5-08ff-4ceb-8adb-2eea94b90238          valeria   churchlandlab
# 32  6af88109-8b3d-485c-8486-f8b35d2bf061          valeria   churchlandlab
# 26  56b81bb0-fffb-4875-9cd6-29465782fb0e          valeria   churchlandlab
# 1   034c07c5-69b0-48c7-ab3e-e491e4dbb725          valeria   churchlandlab
# 12  278bf922-073e-4ef4-90b5-ccf4e25e08fe          valeria   churchlandlab
# 19  3e97e1d3-2a0f-44e5-b63f-36196d78457a          valeria   churchlandlab
# 9   1fce4668-e99f-4e50-9f75-961842781a23          valeria   churchlandlab
# 16  34d5b181-e7c8-4022-aab7-fce1e2640b57          valeria   churchlandlab
# 25  55381f61-4e47-4baa-beb9-70068c0ad62c          valeria   churchlandlab
# 22  50883573-cf52-409f-907a-3920ed1fe479          valeria   churchlandlab
# 10  216d58b3-9a24-4f95-95dc-af5fcefa761f        alejandro       cortexlab
# 14  2f3f45d6-31ac-46fe-8ce2-779c84da427f            charu       cortexlab
# 51  ceba369e-50e8-456f-b248-0f8091ebf2db             nick       cortexlab
# 33  7afdde29-d3b7-4f2f-bc9f-d90a39dbe6f4         hernando  mrsicflogellab
# 40  9e4cdc50-1d31-40c2-9e59-c39ee0cfce7f        alejandro       wittenlab
# 38  8e283b43-3a44-4f30-b292-d6d975c7f935        alejandro       wittenlab
# 24  54edfc98-ce84-471c-94a3-c748552fbc22        alejandro       wittenlab
# 18  3d9f702a-3e39-497c-ac78-49b43527ac0d        alejandro       wittenlab
# 41  9ffded1f-0ccb-45da-99e4-36eb242b7666           chrisk        zadorlab
# 17  37c8f897-cbcc-4743-bad6-764ccbbfb190          valeria        zadorlab
# 6   1229561e-850d-4cd5-bfcb-3d99a87c6de1          valeria        zadorlab
# 46  be2c4e29-f9a6-4e23-b3b9-d1b97bcacff0          valeria        zadorlab
# 50  ca5b07c6-ecec-47be-9de6-4706c04d2ac9          valeria        zadorlab
# 47  c0bdc8f0-b69a-46b2-bd02-28c39d4d0a97          valeria        zadorlab
# 31  6912fe58-e41f-4733-9e1b-552d1552fb0c          valeria        zadorlab
# 36  8d2f70f6-66a8-4b37-b1b1-b191c051824c          valeria        zadorlab
# 52  d43200a5-a79a-4aa3-922d-82a4e2c58c24          valeria        zadorlab
# 0   0026c82d-39e4-4c6b-acb3-303eb4b24f05          valeria        zadorlab
# 27  5df5f18e-b6a1-4e1c-8149-525952d8cdde          valeria        zadorlab
# 5   122205e8-0a31-41ce-9632-30e7857a959d          valeria        zadorlab
# 45  ba34b1e3-7e70-4016-bb91-7bb97f6f8c7a          valeria        zadorlab
# 42  a73f0647-f566-4ded-98f8-7e4f6a18f37b          valeria        zadorlab
# 39  99c07e09-7261-442d-b740-185b7d2086c5          valeria        zadorlab
# 44  b04d788e-cc39-40a5-8be9-d8c9c865abce          valeria        zadorlab
# 3   0d3d977a-0263-46a9-aaa1-0139f473e811          valeria        zadorlab
# 8   1f413ca0-2584-4307-8c5b-918bc17771f7          valeria        zadorlab
# 48  c5ecfe21-ca1f-4024-b694-5ed53d2da11a          valeria        zadorlab
# 13  2ce41c85-6e8f-4b0b-b2a6-4e172c0584f7          valeria        zadorlab
# 30  6904fd86-a05a-4a0e-9c3d-fbaa2c4eb3aa          valeria        zadorlab
# 49  c7a44209-9fe2-42ec-9fbf-13ecb3a0f8a3          valeria        zadorlab
# 37  8dd70a83-b5d2-4c6c-86f4-e2bb33ab727d          valeria        zadorlab
# 7   146f0531-6eb1-4af2-b179-f7fa5a7289e1          valeria        zadorlab
# 53  daada216-464d-4986-8e63-5ae2f470b3fd          valeria        zadorlab
# 35  885bd129-55a7-4043-acdc-80bc7d96b4a5          valeria        zadorlab
# 15  2fda7778-75f3-439b-9702-9a69b6f084d9          valeria        zadorlab
#
#    subject_nickname             subject_line subject_source subject_strain
# 21       test_human                     None           None   Homo sapiens
# 23            IBL_1                     None  Charles River       C57BL/6N
# 34           IBL_10                     None  Charles River       C57BL/6N
# 20           IBL_11                     None  Charles River       C57BL/6N
# 28           IBL_12                     None  Charles River       C57BL/6N
# 4            IBL_13                     None  Charles River       C57BL/6N
# 57           IBL_15                     None  Charles River       C57BL/6N
# 2            IBL_16                     None  Charles River       C57BL/6N
# 11           IBL_17                     None  Charles River       C57BL/6N
# 56           IBL_18                     None  Charles River       C57BL/6N
# 55           IBL_19                     None  Charles River       C57BL/6N
# 29           IBL_20                     None  Charles River       C57BL/6N
# 43           IBL_21                     None  Charles River       C57BL/6N
# 54           IBL_22                     None  Charles River       C57BL/6N
# 32           IBL_23                     None  Charles River       C57BL/6N
# 26           IBL_24                     None  Charles River       C57BL/6N
# 1            IBL_25                     None  Charles River       C57BL/6N
# 12           IBL_26                     None  Charles River       C57BL/6N
# 19           IBL_34                     None  Charles River       C57BL/6N
# 9            IBL_36                     None  Charles River       C57BL/6N
# 16           IBL_45                     None  Charles River       C57BL/6N
# 25           IBL_46                     None  Charles River       C57BL/6N
# 22           IBL_47                     None  Charles River       C57BL/6N
# 10            fip_2                     None           None           None
# 14           dop_11                     None           None           None
# 51           Muller  RCL-GCaMP6f x VGlut-Cre  Cruciform BSU           None
# 33          IBL_004                     None           None           None
# 40    ibl_witten_01                     None      Princeton        Dat-Cre
# 38    ibl_witten_02                     None            Jax       C57BL/6J
# 24    ibl_witten_03                     None      Princeton       C57BL/6J
# 18    ibl_witten_09                     None            Jax       C57BL/6J
# 41    example_CSHL1                     None  Charles River       C57BL/6N
# 17           IBL_14                     None  Charles River       C57BL/6N
# 6             IBL_2                     None  Charles River       C57BL/6N
# 46           IBL_27                     None  Charles River       C57BL/6N
# 50           IBL_28                     None  Charles River       C57BL/6N
# 47           IBL_29                     None  Charles River       C57BL/6N
# 31            IBL_3                     None  Charles River       C57BL/6N
# 36           IBL_30                     None  Charles River       C57BL/6N
# 52           IBL_31                     None  Charles River       C57BL/6N
# 0            IBL_32                     None  Charles River       C57BL/6N
# 27           IBL_33                     None  Charles River       C57BL/6N
# 5            IBL_35                     None  Charles River       C57BL/6N
# 45           IBL_37                     None  Charles River       C57BL/6N
# 42           IBL_38                     None  Charles River       C57BL/6N
# 39           IBL_39                     None  Charles River       C57BL/6N
# 44            IBL_4                     None  Charles River       C57BL/6N
# 3            IBL_40                     None  Charles River       C57BL/6N
# 8            IBL_41                     None  Charles River       C57BL/6N
# 48           IBL_42                     None  Charles River       C57BL/6N
# 13           IBL_43                     None  Charles River       C57BL/6N
# 30           IBL_44                     None  Charles River       C57BL/6N
# 49            IBL_5                     None  Charles River       C57BL/6N
# 37            IBL_6                     None  Charles River       C57BL/6N
# 7             IBL_7                     None  Charles River       C57BL/6N
# 53            IBL_8                     None  Charles River       C57BL/6N
# 35            IBL_9                     None  Charles River       C57BL/6N
# 15      VAR-IBL-002                     None  Charles River       C57BL/6J

# %%
print('# of animals without listed line or strain')
sjs.groupby(['responsible_user'])['subject_nickname'].nunique().reset_index()
# Out:
# # of animals without listed line or strain
#   responsible_user  subject_nickname
# 0        alejandro                 5
# 1            charu                 1
# 2           chrisk                 1
# 3         hernando                 1
# 4             nick                 1
# 5   sfn_booth_user                 1
# 6          valeria                48

# %%
print('# of animals without listed line or strain')
sjs.groupby(['responsible_user'])['subject_nickname'].nunique().reset_index()
# Out:
# # of animals without listed line or strain
#   responsible_user  subject_nickname
# 0        alejandro                 5
# 1            charu                 1
# 2           chrisk                 1
# 3         hernando                 1
# 4             nick                 1
# 5   sfn_booth_user                 1
# 6          valeria                48
