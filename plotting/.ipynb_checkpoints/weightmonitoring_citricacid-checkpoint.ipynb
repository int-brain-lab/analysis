# %%
import matplotlib
import matplotlib.pyplot as plt
from IPython import embed as shell
import numpy as np
import pandas as pd
import scipy as sp

## READ DATA IN FROM GOOGLE DOCS ##
# see http://gspread.readthedocs.io/en/latest/oauth2.html
import gspread
from oauth2client.service_account import ServiceAccountCredentials
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('/Users/urai/Documents/stuff/IBL-CSHL-citricAcid-4e1268c95407.json', scope)
gc = gspread.authorize(credentials)

# now read the doc
doc = gc.open_by_key('1Ne466FpvhqbMQIfuivZRhp_3alBVTgPGSMc0q387frk')

# %%
# read all worksheets, make a dictionary with the info that we'll need to add
worksheet_list = [
    {"sheet": "Batch1", "baseline": "free hydrogel", "intervention": "citric acid water"},
    {"sheet": "Batch2", "baseline": "water restriction", "intervention": "citric acid water"},
    {"sheet": "Batch3", "baseline": "free hydrogel", "intervention": "citric acid hydrogel"},
    {"sheet": "Batch4", "baseline": "water restriction", "intervention": "citric acid hydrogel"},
    ]
df = pd.DataFrame

for w, entry in enumerate(worksheet_list):
    worksheet = doc.worksheet(entry["sheet"])
    df1 = pd.DataFrame(worksheet.get_all_records())
    df1.drop(['Date', ''], axis=1, inplace=True) # get rid of extra stuff
    df1.rename(index=str, columns={"Date_rel": "date"}, inplace=True)

    # unstack into variables Date, Mouse, Baseline, Intervention, Weight
    # https://deparkes.co.uk/2016/10/28/reshape-pandas-data-with-melt/
    df1 = pd.melt(df1, id_vars="date", var_name="mouse", value_name="weight")
    
    # add some info
    df1['baseline'] = "free hydrogel"
    df1['intervention'] = "citric acid water"

    # to do: append across worksheets
    
df1.head(n=20)
# Out:
#     date   mouse weight       baseline       intervention
# 0      0  IBL_13   22.5  free hydrogel  citric acid water
# 1      1  IBL_13  22.17  free hydrogel  citric acid water
# 2      2  IBL_13     24  free hydrogel  citric acid water
# 3      3  IBL_13     25  free hydrogel  citric acid water
# 4      4  IBL_13     25  free hydrogel  citric acid water
# 5      5  IBL_13  25.05  free hydrogel  citric acid water
# 6      6  IBL_13         free hydrogel  citric acid water
# 7      7  IBL_13         free hydrogel  citric acid water
# 8      8  IBL_13         free hydrogel  citric acid water
# 9      0  IBL_14  23.36  free hydrogel  citric acid water
# 10     1  IBL_14  23.29  free hydrogel  citric acid water
# 11     2  IBL_14     24  free hydrogel  citric acid water
# 12     3  IBL_14     25  free hydrogel  citric acid water
# 13     4  IBL_14     26  free hydrogel  citric acid water
# 14     5  IBL_14  25.88  free hydrogel  citric acid water
# 15     6  IBL_14         free hydrogel  citric acid water
# 16     7  IBL_14         free hydrogel  citric acid water
# 17     8  IBL_14         free hydrogel  citric acid water
# 18     0  IBL_15  22.81  free hydrogel  citric acid water
# 19     1  IBL_15  22.93  free hydrogel  citric acid water
